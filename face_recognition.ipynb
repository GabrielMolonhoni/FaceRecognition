# %%
import tensorflow as tf
from tensorflow.python.platform import gfile
from tensorflow.python.framework import ops
from sklearn.svm import SVC
import numpy as np
import cv2
import os
import pickle

import warnings
warnings.filterwarnings("ignore")

# %%
class ImageClass():
    "Stores the paths to images for a given class"
    def __init__(self, name, image_paths):
        self.name = name
        self.image_paths = image_paths
  
    def __str__(self):
        return self.name + ', ' + str(len(self.image_paths)) + ' images'
  
    def __len__(self):
        return len(self.image_paths)

def load_dataset(path, train = True):
    dataset = []

    classes = os.listdir(path)
    classes.sort()

    if train:
        for i in range(len(classes)):
            class_name = classes[i]
            face_dir = os.path.join(path, class_name)
            image_paths = get_image_paths(face_dir)
            dataset.append(ImageClass(class_name, image_paths))
    else:
        image_paths = get_image_paths(path)
        dataset.append(image_paths)

    return dataset

def load_train_dataset():
    train_path = './dataset/train'    
    return load_dataset(train_path)

def load_test_dataset():
    test_path = './dataset/test'  
    return load_dataset(test_path, train=False)

def get_image_paths(dir_path):
    image_paths = []
    if os.path.isdir(dir_path):
        images = os.listdir(dir_path)
        image_paths = [os.path.join(dir_path,img) for img in images]
    return image_paths

def get_image_paths_and_labels(dataset):
    image_paths_flat = []
    labels_flat = []
    for i in range(len(dataset)):
        image_paths_flat += dataset[i].image_paths
        labels_flat += [i] * len(dataset[i].image_paths)
    return image_paths_flat, labels_flat

# %%
import math
import cv2
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix 

class facenet_utils:

    def __init__(self, dataset = None, train = None):
        if train is not None:
            self.dataset = dataset
            self.paths, self.labels = get_image_paths_and_labels(dataset)
        else:
            if dataset is not None:
                self.dataset = dataset

        self.emb_array = None
        


    def load_model(self):
        model_filename = './models/20180402-114759.pb'
        
        model_filename = os.path.expanduser(model_filename)
        if (os.path.isfile(model_filename)):
            print(f'Model filename: {model_filename}')
            with tf.io.gfile.GFile(model_filename, 'rb') as f:
                graph_def = tf.compat.v1.GraphDef()
                graph_def.ParseFromString(f.read())
                tf.import_graph_def(graph_def, name='')
        else:
            print('File not found!')  

    def load_classifier(self):
        classifier_filename = './models/my_classifier.pkl'
        classifier_filename_exp = os.path.expanduser(classifier_filename)
        with open(classifier_filename_exp, 'rb') as infile:
            (model, class_names) = pickle.load(infile)
        print(f'loaded classifier file->{classifier_filename_exp}')
        return model, class_names

    def prewhiten(self, x):
        mean = np.mean(x)
        std = np.std(x)
        std_adj = np.maximum(std, 1.0/np.sqrt(x.size))
        y = np.multiply(np.subtract(x, mean), 1/std_adj)
        return y 

    def to_rgb(self, img):
        w, h = img.shape
        ret = np.empty((w, h, 3), dtype=np.uint8)
        ret[:, :, 0] = ret[:, :, 1] = ret[:, :, 2] = img
        return ret

    def to_rgb(img):
        w, h = img.shape
        ret = np.empty((w, h, 3), dtype=np.uint8)
        ret[:, :, 0] = ret[:, :, 1] = ret[:, :, 2] = img
        return ret

    def load_images(self, image_paths, image_size,  do_prewhiten=True):    
        images = np.zeros((len(image_paths), image_size, image_size, 3))
        print('Loading images...')
        for i in range(len(image_paths)):
            img = cv2.imread(image_paths[i])
            if img.ndim == 2:
                img = self.to_rgb(img)

            img = cv2.resize(img, (160, 160))
            
            if do_prewhiten:
                img = self.prewhiten(img)
            images[i,:,:,:] = img
        print('Images loaded')
        return images      
    

    def calculate_embeddings(self, session):

        images_placeholder = tf.compat.v1.get_default_graph().get_tensor_by_name("input:0")
        embeddings = tf.compat.v1.get_default_graph().get_tensor_by_name("embeddings:0")
        phase_train_placeholder = tf.compat.v1.get_default_graph().get_tensor_by_name("phase_train:0")
        embedding_size = embeddings.get_shape()[1]

        # Run forward pass to calculate embeddings
        print('Calculating features for images')
        batch_size = 2000
        image_size = 160
        nrof_images = len(paths)
        nrof_batches_per_epoch = int(math.ceil(1.0 * len(paths) / batch_size))
        self.emb_array = np.zeros((len(paths), embedding_size))
        for i in range(nrof_batches_per_epoch):
            print(f'Batch {i} of {nrof_batches_per_epoch}')
            start_index = i * batch_size
            end_index = min((i + 1) * batch_size, len(paths))
            paths_batch = paths[start_index:end_index]
            images = self.load_images(paths_batch, image_size)
            feed_dict = {images_placeholder: images, phase_train_placeholder: False}
            print('Calculating array of features')
            self.emb_array[start_index:end_index, :] = session.run(embeddings, feed_dict=feed_dict)
            print('Done')

    def train_classifier(self):
        classifier_filename = './models/my_classifier.pkl'
        classifier_filename_exp = os.path.expanduser(classifier_filename)

        param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf', 'poly', 'sigmoid']} 
        
        grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=2)
        grid.fit(self.emb_array,self.labels)           

        # Train classifier
        print('Training classifier')
        model = SVC(kernel='rbf', probability=True)
        model.fit(self.emb_array, self.labels)

        # Create a list of class names
        class_names = [cls.name.replace('_', ' ') for cls in dataset]
        print(class_names)

        print(grid.best_estimator_)

        grid_predictions = grid.predict(self.emb_array)
        print(confusion_matrix(self.labels,grid_predictions))
        print(classification_report(self.labels,grid_predictions))

        # Saving classifier model
        with open(classifier_filename_exp, 'wb+') as outfile:
            pickle.dump((model, class_names), outfile)
        print(f'Saved classifier model to file {classifier_filename_exp}')


    def train_model_svm(self):        
        with tf.compat.v1.Session() as sess:
            self.load_model()  
            self.calculate_embeddings(sess)
            self.train_classifier()

    def get_img_embeddings(self, session, img):
        images_placeholder = tf.compat.v1.get_default_graph().get_tensor_by_name("input:0")
        embeddings = tf.compat.v1.get_default_graph().get_tensor_by_name("embeddings:0")
        phase_train_placeholder = tf.compat.v1.get_default_graph().get_tensor_by_name("phase_train:0")
        embedding_size = embeddings.get_shape()[1]

        self.emb_array = np.zeros((1, embedding_size))

        image = np.zeros((1, 160, 160, 3))

        if img.ndim == 2:
            img = self.to_rgb(img)
        img = cv2.resize(img, (160, 160))
        img = self.prewhiten(img)
        image[0,:,:,:] = img

        feed_dict = {images_placeholder: image, phase_train_placeholder: False}
        self.emb_array[0, :] = session.run(embeddings, feed_dict=feed_dict)

        return self.emb_array

# %%
dataset = load_train_dataset()
paths, labels = get_image_paths_and_labels(dataset)

facenet = facenet_utils(dataset=dataset, train=True)
facenet.train_model_svm()
# Out:
# Model filename: ./models/20180402-114759.pb
# Calculating features for images
# Batch 0 of 7
# Loading images...
# Images loaded
# Calculating array of features
# Done
# Batch 1 of 7
# Loading images...
# Images loaded
# Calculating array of features
# Done
# Batch 2 of 7
# Loading images...
# Images loaded
# Calculating array of features
# Done
# Batch 3 of 7
# Loading images...
# Images loaded
# Calculating array of features
# Done
# Batch 4 of 7
# Loading images...
# Images loaded
# Calculating array of features
# Done
# Batch 5 of 7
# Loading images...
# Images loaded
# Calculating array of features
# Done
# Batch 6 of 7
# Loading images...
# Images loaded
# Calculating array of features
# Done
# Fitting 5 folds for each of 75 candidates, totalling 375 fits
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=  19.3s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=  19.9s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=  19.6s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=  19.6s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=  20.3s
# [CV] END ........................C=0.1, gamma=1, kernel=poly; total time=  18.4s
# [CV] END ........................C=0.1, gamma=1, kernel=poly; total time=  17.6s
# [CV] END ........................C=0.1, gamma=1, kernel=poly; total time=  16.6s
# [CV] END ........................C=0.1, gamma=1, kernel=poly; total time=  16.5s
# [CV] END ........................C=0.1, gamma=1, kernel=poly; total time=  16.4s
# [CV] END .....................C=0.1, gamma=1, kernel=sigmoid; total time=  14.1s
# [CV] END .....................C=0.1, gamma=1, kernel=sigmoid; total time=  13.8s
# [CV] END .....................C=0.1, gamma=1, kernel=sigmoid; total time=  14.0s
# [CV] END .....................C=0.1, gamma=1, kernel=sigmoid; total time=  14.2s
# [CV] END .....................C=0.1, gamma=1, kernel=sigmoid; total time=  13.9s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=  24.1s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=  23.5s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=  24.6s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=  24.8s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=  24.7s
# [CV] END ......................C=0.1, gamma=0.1, kernel=poly; total time=  20.2s
# [CV] END ......................C=0.1, gamma=0.1, kernel=poly; total time=  20.4s
# [CV] END ......................C=0.1, gamma=0.1, kernel=poly; total time=  21.9s
# [CV] END ......................C=0.1, gamma=0.1, kernel=poly; total time=  19.7s
# [CV] END ......................C=0.1, gamma=0.1, kernel=poly; total time=  21.4s
# [CV] END ...................C=0.1, gamma=0.1, kernel=sigmoid; total time=  21.8s
# [CV] END ...................C=0.1, gamma=0.1, kernel=sigmoid; total time=  22.2s
# [CV] END ...................C=0.1, gamma=0.1, kernel=sigmoid; total time=  22.0s
# [CV] END ...................C=0.1, gamma=0.1, kernel=sigmoid; total time=  22.2s
# [CV] END ...................C=0.1, gamma=0.1, kernel=sigmoid; total time=  22.5s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=  24.9s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=  25.2s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=  25.4s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=  25.1s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=  24.2s
# [CV] END .....................C=0.1, gamma=0.01, kernel=poly; total time=  19.8s
# [CV] END .....................C=0.1, gamma=0.01, kernel=poly; total time=  21.4s
# [CV] END .....................C=0.1, gamma=0.01, kernel=poly; total time=  19.5s
# [CV] END .....................C=0.1, gamma=0.01, kernel=poly; total time=  20.1s
# [CV] END .....................C=0.1, gamma=0.01, kernel=poly; total time=  20.4s
# [CV] END ..................C=0.1, gamma=0.01, kernel=sigmoid; total time=  23.3s
# [CV] END ..................C=0.1, gamma=0.01, kernel=sigmoid; total time=  22.4s
# [CV] END ..................C=0.1, gamma=0.01, kernel=sigmoid; total time=  22.6s
# [CV] END ..................C=0.1, gamma=0.01, kernel=sigmoid; total time=  22.8s
# [CV] END ..................C=0.1, gamma=0.01, kernel=sigmoid; total time=  22.6s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=  25.1s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=  25.3s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=  24.9s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=  24.6s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=  24.0s
# [CV] END ....................C=0.1, gamma=0.001, kernel=poly; total time=  19.4s
# [CV] END ....................C=0.1, gamma=0.001, kernel=poly; total time=  20.2s
# [CV] END ....................C=0.1, gamma=0.001, kernel=poly; total time=  20.5s
# [CV] END ....................C=0.1, gamma=0.001, kernel=poly; total time=  21.2s
# [CV] END ....................C=0.1, gamma=0.001, kernel=poly; total time=  20.5s
# [CV] END .................C=0.1, gamma=0.001, kernel=sigmoid; total time=  20.9s
# [CV] END .................C=0.1, gamma=0.001, kernel=sigmoid; total time=  20.8s
# [CV] END .................C=0.1, gamma=0.001, kernel=sigmoid; total time=  21.5s
# [CV] END .................C=0.1, gamma=0.001, kernel=sigmoid; total time=  20.4s
# [CV] END .................C=0.1, gamma=0.001, kernel=sigmoid; total time=  21.3s
# [CV] END ....................C=0.1, gamma=0.0001, kernel=rbf; total time=  25.3s
# [CV] END ....................C=0.1, gamma=0.0001, kernel=rbf; total time=  24.3s
# [CV] END ....................C=0.1, gamma=0.0001, kernel=rbf; total time=  24.5s
# [CV] END ....................C=0.1, gamma=0.0001, kernel=rbf; total time=  23.9s
# [CV] END ....................C=0.1, gamma=0.0001, kernel=rbf; total time=  24.0s
# [CV] END ...................C=0.1, gamma=0.0001, kernel=poly; total time=  20.5s
# [CV] END ...................C=0.1, gamma=0.0001, kernel=poly; total time=  19.3s
# [CV] END ...................C=0.1, gamma=0.0001, kernel=poly; total time=  19.7s
# [CV] END ...................C=0.1, gamma=0.0001, kernel=poly; total time=  20.4s
# [CV] END ...................C=0.1, gamma=0.0001, kernel=poly; total time=  20.1s
# [CV] END ................C=0.1, gamma=0.0001, kernel=sigmoid; total time=  22.0s
# [CV] END ................C=0.1, gamma=0.0001, kernel=sigmoid; total time=  21.3s
# [CV] END ................C=0.1, gamma=0.0001, kernel=sigmoid; total time=  22.0s
# [CV] END ................C=0.1, gamma=0.0001, kernel=sigmoid; total time=  21.3s
# [CV] END ................C=0.1, gamma=0.0001, kernel=sigmoid; total time=  21.2s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=  13.3s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=  12.5s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=  13.3s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=  12.2s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=  12.4s
# [CV] END ..........................C=1, gamma=1, kernel=poly; total time=  11.1s
# [CV] END ..........................C=1, gamma=1, kernel=poly; total time=  11.2s
# [CV] END ..........................C=1, gamma=1, kernel=poly; total time=  11.8s
# [CV] END ..........................C=1, gamma=1, kernel=poly; total time=  11.7s
# [CV] END ..........................C=1, gamma=1, kernel=poly; total time=  11.6s
# [CV] END .......................C=1, gamma=1, kernel=sigmoid; total time=   7.2s
# [CV] END .......................C=1, gamma=1, kernel=sigmoid; total time=   7.3s
# [CV] END .......................C=1, gamma=1, kernel=sigmoid; total time=   7.2s
# [CV] END .......................C=1, gamma=1, kernel=sigmoid; total time=   7.2s
# [CV] END .......................C=1, gamma=1, kernel=sigmoid; total time=   7.3s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=  14.2s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=  14.4s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=  14.1s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=  14.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=  14.3s
# [CV] END ........................C=1, gamma=0.1, kernel=poly; total time=  20.6s
# [CV] END ........................C=1, gamma=0.1, kernel=poly; total time=  20.9s
# [CV] END ........................C=1, gamma=0.1, kernel=poly; total time=  21.9s
# [CV] END ........................C=1, gamma=0.1, kernel=poly; total time=  21.8s
# [CV] END ........................C=1, gamma=0.1, kernel=poly; total time=  20.4s
# [CV] END .....................C=1, gamma=0.1, kernel=sigmoid; total time=  13.1s
# [CV] END .....................C=1, gamma=0.1, kernel=sigmoid; total time=  13.9s
# [CV] END .....................C=1, gamma=0.1, kernel=sigmoid; total time=  13.6s
# [CV] END .....................C=1, gamma=0.1, kernel=sigmoid; total time=  13.5s
# [CV] END .....................C=1, gamma=0.1, kernel=sigmoid; total time=  13.7s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=  23.5s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=  23.3s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=  23.6s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=  25.6s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=  25.9s
# [CV] END .......................C=1, gamma=0.01, kernel=poly; total time=  21.8s
# [CV] END .......................C=1, gamma=0.01, kernel=poly; total time=  22.3s
# [CV] END .......................C=1, gamma=0.01, kernel=poly; total time=  22.5s
# [CV] END .......................C=1, gamma=0.01, kernel=poly; total time=  19.4s
# [CV] END .......................C=1, gamma=0.01, kernel=poly; total time=  19.9s
# [CV] END ....................C=1, gamma=0.01, kernel=sigmoid; total time=  23.6s
# [CV] END ....................C=1, gamma=0.01, kernel=sigmoid; total time=  22.8s
# [CV] END ....................C=1, gamma=0.01, kernel=sigmoid; total time=  23.5s
# [CV] END ....................C=1, gamma=0.01, kernel=sigmoid; total time=  24.1s
# [CV] END ....................C=1, gamma=0.01, kernel=sigmoid; total time=  23.7s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=  24.6s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=  25.4s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=  24.9s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=  25.1s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=  24.9s
# [CV] END ......................C=1, gamma=0.001, kernel=poly; total time=  20.2s
# [CV] END ......................C=1, gamma=0.001, kernel=poly; total time=  21.6s
# [CV] END ......................C=1, gamma=0.001, kernel=poly; total time=  19.6s
# [CV] END ......................C=1, gamma=0.001, kernel=poly; total time=  21.1s
# [CV] END ......................C=1, gamma=0.001, kernel=poly; total time=  20.9s
# [CV] END ...................C=1, gamma=0.001, kernel=sigmoid; total time=  21.5s
# [CV] END ...................C=1, gamma=0.001, kernel=sigmoid; total time=  22.6s
# [CV] END ...................C=1, gamma=0.001, kernel=sigmoid; total time=  23.3s
# [CV] END ...................C=1, gamma=0.001, kernel=sigmoid; total time=  24.3s
# [CV] END ...................C=1, gamma=0.001, kernel=sigmoid; total time=  23.6s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=  26.4s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=  27.6s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=  24.9s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=  25.3s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=  24.1s
# [CV] END .....................C=1, gamma=0.0001, kernel=poly; total time=  20.0s
# [CV] END .....................C=1, gamma=0.0001, kernel=poly; total time=  20.2s
# [CV] END .....................C=1, gamma=0.0001, kernel=poly; total time=  20.4s
# [CV] END .....................C=1, gamma=0.0001, kernel=poly; total time=  20.8s
# [CV] END .....................C=1, gamma=0.0001, kernel=poly; total time=  20.1s
# [CV] END ..................C=1, gamma=0.0001, kernel=sigmoid; total time=  24.2s
# [CV] END ..................C=1, gamma=0.0001, kernel=sigmoid; total time=  24.2s
# [CV] END ..................C=1, gamma=0.0001, kernel=sigmoid; total time=  24.2s
# [CV] END ..................C=1, gamma=0.0001, kernel=sigmoid; total time=  24.4s
# [CV] END ..................C=1, gamma=0.0001, kernel=sigmoid; total time=  24.4s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=  13.9s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=  11.8s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=  11.8s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=  12.3s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=  12.1s
# [CV] END .........................C=10, gamma=1, kernel=poly; total time=  11.5s
# [CV] END .........................C=10, gamma=1, kernel=poly; total time=  11.6s
# [CV] END .........................C=10, gamma=1, kernel=poly; total time=  11.7s
# [CV] END .........................C=10, gamma=1, kernel=poly; total time=  11.2s
# [CV] END .........................C=10, gamma=1, kernel=poly; total time=  11.5s
# [CV] END ......................C=10, gamma=1, kernel=sigmoid; total time=   5.5s
# [CV] END ......................C=10, gamma=1, kernel=sigmoid; total time=   5.8s
# [CV] END ......................C=10, gamma=1, kernel=sigmoid; total time=   5.5s
# [CV] END ......................C=10, gamma=1, kernel=sigmoid; total time=   5.9s
# [CV] END ......................C=10, gamma=1, kernel=sigmoid; total time=   6.6s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=  11.2s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=  10.3s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=  10.0s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=  10.2s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=  10.2s
# [CV] END .......................C=10, gamma=0.1, kernel=poly; total time=  22.3s
# [CV] END .......................C=10, gamma=0.1, kernel=poly; total time=  21.8s
# [CV] END .......................C=10, gamma=0.1, kernel=poly; total time=  21.7s
# [CV] END .......................C=10, gamma=0.1, kernel=poly; total time=  21.2s
# [CV] END .......................C=10, gamma=0.1, kernel=poly; total time=  23.3s
# [CV] END ....................C=10, gamma=0.1, kernel=sigmoid; total time=   9.6s
# [CV] END ....................C=10, gamma=0.1, kernel=sigmoid; total time=   9.6s
# [CV] END ....................C=10, gamma=0.1, kernel=sigmoid; total time=   9.3s
# [CV] END ....................C=10, gamma=0.1, kernel=sigmoid; total time=   9.5s
# [CV] END ....................C=10, gamma=0.1, kernel=sigmoid; total time=   9.6s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=  16.8s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=  16.6s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=  15.9s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=  14.4s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=  13.6s
# [CV] END ......................C=10, gamma=0.01, kernel=poly; total time=  20.6s
# [CV] END ......................C=10, gamma=0.01, kernel=poly; total time=  20.3s
# [CV] END ......................C=10, gamma=0.01, kernel=poly; total time=  20.4s
# [CV] END ......................C=10, gamma=0.01, kernel=poly; total time=  22.6s
# [CV] END ......................C=10, gamma=0.01, kernel=poly; total time=  22.5s
# [CV] END ...................C=10, gamma=0.01, kernel=sigmoid; total time=  15.5s
# [CV] END ...................C=10, gamma=0.01, kernel=sigmoid; total time=  15.5s
# [CV] END ...................C=10, gamma=0.01, kernel=sigmoid; total time=  15.4s
# [CV] END ...................C=10, gamma=0.01, kernel=sigmoid; total time=  15.5s
# [CV] END ...................C=10, gamma=0.01, kernel=sigmoid; total time=  15.8s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=  26.6s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=  26.4s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=  27.4s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=  26.3s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=  26.0s
# [CV] END .....................C=10, gamma=0.001, kernel=poly; total time=  22.4s
# [CV] END .....................C=10, gamma=0.001, kernel=poly; total time=  22.3s
# [CV] END .....................C=10, gamma=0.001, kernel=poly; total time=  22.5s
# [CV] END .....................C=10, gamma=0.001, kernel=poly; total time=  23.4s
# [CV] END .....................C=10, gamma=0.001, kernel=poly; total time=  23.3s
# [CV] END ..................C=10, gamma=0.001, kernel=sigmoid; total time=  22.4s
# [CV] END ..................C=10, gamma=0.001, kernel=sigmoid; total time=  20.7s
# [CV] END ..................C=10, gamma=0.001, kernel=sigmoid; total time=  21.6s
# [CV] END ..................C=10, gamma=0.001, kernel=sigmoid; total time=  22.0s
# [CV] END ..................C=10, gamma=0.001, kernel=sigmoid; total time=  21.2s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=  25.0s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=  24.5s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=  24.7s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=  24.9s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=  25.5s
# [CV] END ....................C=10, gamma=0.0001, kernel=poly; total time=  21.2s
# [CV] END ....................C=10, gamma=0.0001, kernel=poly; total time=  20.9s
# [CV] END ....................C=10, gamma=0.0001, kernel=poly; total time=  20.8s
# [CV] END ....................C=10, gamma=0.0001, kernel=poly; total time=  20.9s
# [CV] END ....................C=10, gamma=0.0001, kernel=poly; total time=  20.0s
# [CV] END .................C=10, gamma=0.0001, kernel=sigmoid; total time=  21.5s
# [CV] END .................C=10, gamma=0.0001, kernel=sigmoid; total time=  21.6s
# [CV] END .................C=10, gamma=0.0001, kernel=sigmoid; total time=  21.3s
# [CV] END .................C=10, gamma=0.0001, kernel=sigmoid; total time=  22.5s
# [CV] END .................C=10, gamma=0.0001, kernel=sigmoid; total time=  21.3s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=  12.1s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=  11.8s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=  13.2s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\gmolo\Documents\Projetos\Face Recognition\FaceRecognition\face_recognition.ipynb Cell 4 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/gmolo/Documents/Projetos/Face%20Recognition/FaceRecognition/face_recognition.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> paths, labels = get_image_paths_and_labels(dataset)
#       <a href='vscode-notebook-cell:/c%3A/Users/gmolo/Documents/Projetos/Face%20Recognition/FaceRecognition/face_recognition.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> facenet = facenet_utils(dataset=dataset, train=True)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gmolo/Documents/Projetos/Face%20Recognition/FaceRecognition/face_recognition.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> facenet.train_model_svm()
#
# c:\Users\gmolo\Documents\Projetos\Face Recognition\FaceRecognition\face_recognition.ipynb Cell 4 in facenet_utils.train_model_svm(self)
#     <a href='vscode-notebook-cell:/c%3A/Users/gmolo/Documents/Projetos/Face%20Recognition/FaceRecognition/face_recognition.ipynb#W3sZmlsZQ%3D%3D?line=135'>136</a> self.load_model()
#     <a href='vscode-notebook-cell:/c%3A/Users/gmolo/Documents/Projetos/Face%20Recognition/FaceRecognition/face_recognition.ipynb#W3sZmlsZQ%3D%3D?line=136'>137</a> self.calculate_embeddings(sess)
# --> <a href='vscode-notebook-cell:/c%3A/Users/gmolo/Documents/Projetos/Face%20Recognition/FaceRecognition/face_recognition.ipynb#W3sZmlsZQ%3D%3D?line=137'>138</a> self.train_classifier()
#
# c:\Users\gmolo\Documents\Projetos\Face Recognition\FaceRecognition\face_recognition.ipynb Cell 4 in facenet_utils.train_classifier(self)
#     <a href='vscode-notebook-cell:/c%3A/Users/gmolo/Documents/Projetos/Face%20Recognition/FaceRecognition/face_recognition.ipynb#W3sZmlsZQ%3D%3D?line=105'>106</a> param_grid = {'C': [0.1, 1, 10, 100, 1000],
#     <a href='vscode-notebook-cell:/c%3A/Users/gmolo/Documents/Projetos/Face%20Recognition/FaceRecognition/face_recognition.ipynb#W3sZmlsZQ%3D%3D?line=106'>107</a>       'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#     <a href='vscode-notebook-cell:/c%3A/Users/gmolo/Documents/Projetos/Face%20Recognition/FaceRecognition/face_recognition.ipynb#W3sZmlsZQ%3D%3D?line=107'>108</a>       'kernel': ['rbf', 'poly', 'sigmoid']}
#     <a href='vscode-notebook-cell:/c%3A/Users/gmolo/Documents/Projetos/Face%20Recognition/FaceRecognition/face_recognition.ipynb#W3sZmlsZQ%3D%3D?line=109'>110</a> grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=2)
# --> <a href='vscode-notebook-cell:/c%3A/Users/gmolo/Documents/Projetos/Face%20Recognition/FaceRecognition/face_recognition.ipynb#W3sZmlsZQ%3D%3D?line=110'>111</a> grid.fit(self.emb_array,self.labels)
#     <a href='vscode-notebook-cell:/c%3A/Users/gmolo/Documents/Projetos/Face%20Recognition/FaceRecognition/face_recognition.ipynb#W3sZmlsZQ%3D%3D?line=112'>113</a> # Train classifier
#     <a href='vscode-notebook-cell:/c%3A/Users/gmolo/Documents/Projetos/Face%20Recognition/FaceRecognition/face_recognition.ipynb#W3sZmlsZQ%3D%3D?line=113'>114</a> print('Training classifier')
#
# File c:\Python310\lib\site-packages\sklearn\model_selection\_search.py:891, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     885     results = self._format_results(
#     886         all_candidate_params, n_splits, all_out, all_more_results
#     887     )
#     889     return results
# --> 891 self._run_search(evaluate_candidates)
#     893 # multimetric is determined here because in the case of a callable
#     894 # self.scoring the return type is only known after calling
#     895 first_test_score = all_out[0]["test_scores"]
#
# File c:\Python310\lib\site-packages\sklearn\model_selection\_search.py:1392, in GridSearchCV._run_search(self, evaluate_candidates)
#    1390 def _run_search(self, evaluate_candidates):
#    1391     """Search all candidates in param_grid"""
# -> 1392     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Python310\lib\site-packages\sklearn\model_selection\_search.py:838, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     830 if self.verbose > 0:
#     831     print(
#     832         "Fitting {0} folds for each of {1} candidates,"
#     833         " totalling {2} fits".format(
#     834             n_splits, n_candidates, n_candidates * n_splits
#     835         )
#     836     )
# --> 838 out = parallel(
#     839     delayed(_fit_and_score)(
#     840         clone(base_estimator),
#     841         X,
#     842         y,
#     843         train=train,
#     844         test=test,
#     845         parameters=parameters,
#     846         split_progress=(split_idx, n_splits),
#     847         candidate_progress=(cand_idx, n_candidates),
#     848         **fit_and_score_kwargs,
#     849     )
#     850     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     851         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     852     )
#     853 )
#     855 if len(out) < 1:
#     856     raise ValueError(
#     857         "No fits were performed. "
#     858         "Was the CV iterator empty? "
#     859         "Were there no candidates?"
#     860     )
#
# File c:\Python310\lib\site-packages\joblib\parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File c:\Python310\lib\site-packages\joblib\parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File c:\Python310\lib\site-packages\joblib\parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File c:\Python310\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\Python310\lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File c:\Python310\lib\site-packages\joblib\parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File c:\Python310\lib\site-packages\joblib\parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File c:\Python310\lib\site-packages\sklearn\utils\fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File c:\Python310\lib\site-packages\sklearn\model_selection\_validation.py:680, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678         estimator.fit(X_train, **fit_params)
#     679     else:
# --> 680         estimator.fit(X_train, y_train, **fit_params)
#     682 except Exception:
#     683     # Note fit time as time until error
#     684     fit_time = time.time() - start_time
#
# File c:\Python310\lib\site-packages\sklearn\svm\_base.py:255, in BaseLibSVM.fit(self, X, y, sample_weight)
#     252     print("[LibSVM]", end="")
#     254 seed = rnd.randint(np.iinfo("i").max)
# --> 255 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     256 # see comment on the other call to np.iinfo in this file
#     258 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File c:\Python310\lib\site-packages\sklearn\svm\_base.py:315, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     302 libsvm.set_verbosity_wrap(self.verbose)
#     304 # we don't pass **self.get_params() to allow subclasses to
#     305 # add other parameters to __init__
#     306 (
#     307     self.support_,
#     308     self.support_vectors_,
#     309     self._n_support,
#     310     self.dual_coef_,
#     311     self.intercept_,
#     312     self._probA,
#     313     self._probB,
#     314     self.fit_status_,
# --> 315 ) = libsvm.fit(
#     316     X,
#     317     y,
#     318     svm_type=solver_type,
#     319     sample_weight=sample_weight,
#     320     class_weight=self.class_weight_,
#     321     kernel=kernel,
#     322     C=self.C,
#     323     nu=self.nu,
#     324     probability=self.probability,
#     325     degree=self.degree,
#     326     shrinking=self.shrinking,
#     327     tol=self.tol,
#     328     cache_size=self.cache_size,
#     329     coef0=self.coef0,
#     330     gamma=self._gamma,
#     331     epsilon=self.epsilon,
#     332     max_iter=self.max_iter,
#     333     random_seed=random_seed,
#     334 )
#     336 self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import accuracy_score
import pandas as pd

test_dataset = load_test_dataset()
print(test_dataset)

facenet_test = facenet_utils()

with tf.compat.v1.Session() as sess:
    facenet_test.load_model()
    model, class_names = facenet_test.load_classifier()
    #print(class_names)

    predicted = {'image-id': [], 'prediction': []}

    for img_path in test_dataset[0]:
        predicted['image-id'].append(int(os.path.basename(img_path).split('.')[0]))
        img = cv2.imread(img_path)
        embeddings = facenet_test.get_img_embeddings(sess, img)
        
        predictions = model.predict_proba(embeddings)
        best_class_indices = np.argmax(predictions, axis=1)
        best_class_probabilities = predictions[np.arange(len(best_class_indices)), best_class_indices]


        for H_i in class_names:
            if class_names[best_class_indices[0]] == H_i:
                result = class_names[best_class_indices[0]]
                predicted['prediction'].append(result)
# Out:
# [['./dataset/test\\0001.jpg', './dataset/test\\0002.jpg', './dataset/test\\0003.jpg', './dataset/test\\0004.jpg', './dataset/test\\0005.jpg', './dataset/test\\0006.jpg', './dataset/test\\0007.jpg', './dataset/test\\0008.jpg', './dataset/test\\0009.jpg', './dataset/test\\0010.jpg', './dataset/test\\0011.jpg', './dataset/test\\0012.jpg', './dataset/test\\0013.jpg', './dataset/test\\0014.jpg', './dataset/test\\0015.jpg', './dataset/test\\0016.jpg', './dataset/test\\0017.jpg', './dataset/test\\0018.jpg', './dataset/test\\0019.jpg', './dataset/test\\0020.jpg', './dataset/test\\0021.jpg', './dataset/test\\0022.jpg', './dataset/test\\0023.jpg', './dataset/test\\0024.jpg', './dataset/test\\0025.jpg', './dataset/test\\0026.jpg', './dataset/test\\0027.jpg', './dataset/test\\0028.jpg', './dataset/test\\0029.jpg', './dataset/test\\0030.jpg', './dataset/test\\0031.jpg', './dataset/test\\0032.jpg', './dataset/test\\0033.jpg', './dataset/test\\0034.jpg', './dataset/test\\0035.jpg', './dataset/test\\0036.jpg', './dataset/test\\0037.jpg', './dataset/test\\0038.jpg', './dataset/test\\0039.jpg', './dataset/test\\0040.jpg', './dataset/test\\0041.jpg', './dataset/test\\0042.jpg', './dataset/test\\0043.jpg', './dataset/test\\0044.jpg', './dataset/test\\0045.jpg', './dataset/test\\0046.jpg', './dataset/test\\0047.jpg', './dataset/test\\0048.jpg', './dataset/test\\0049.jpg', './dataset/test\\0050.jpg', './dataset/test\\0051.jpg', './dataset/test\\0052.jpg', './dataset/test\\0053.jpg', './dataset/test\\0054.jpg', './dataset/test\\0055.jpg', './dataset/test\\0056.jpg', './dataset/test\\0057.jpg', './dataset/test\\0058.jpg', './dataset/test\\0059.jpg', './dataset/test\\0060.jpg', './dataset/test\\0061.jpg', './dataset/test\\0062.jpg', './dataset/test\\0063.jpg', './dataset/test\\0064.jpg', './dataset/test\\0065.jpg', './dataset/test\\0066.jpg', './dataset/test\\0067.jpg', './dataset/test\\0068.jpg', './dataset/test\\0069.jpg', './dataset/test\\0070.jpg', './dataset/test\\0071.jpg', './dataset/test\\0072.jpg', './dataset/test\\0073.jpg', './dataset/test\\0074.jpg', './dataset/test\\0075.jpg', './dataset/test\\0076.jpg', './dataset/test\\0077.jpg', './dataset/test\\0078.jpg', './dataset/test\\0079.jpg', './dataset/test\\0080.jpg', './dataset/test\\0081.jpg', './dataset/test\\0082.jpg', './dataset/test\\0083.jpg', './dataset/test\\0084.jpg', './dataset/test\\0085.jpg', './dataset/test\\0086.jpg', './dataset/test\\0087.jpg', './dataset/test\\0088.jpg', './dataset/test\\0089.jpg', './dataset/test\\0090.jpg', './dataset/test\\0091.jpg', './dataset/test\\0092.jpg', './dataset/test\\0093.jpg', './dataset/test\\0094.jpg', './dataset/test\\0095.jpg', './dataset/test\\0096.jpg', './dataset/test\\0097.jpg', './dataset/test\\0098.jpg', './dataset/test\\0099.jpg', './dataset/test\\0100.jpg', './dataset/test\\0101.jpg', './dataset/test\\0102.jpg', './dataset/test\\0103.jpg', './dataset/test\\0104.jpg', './dataset/test\\0105.jpg', './dataset/test\\0106.jpg', './dataset/test\\0107.jpg', './dataset/test\\0108.jpg', './dataset/test\\0109.jpg', './dataset/test\\0110.jpg', './dataset/test\\0111.jpg', './dataset/test\\0112.jpg', './dataset/test\\0113.jpg', './dataset/test\\0114.jpg', './dataset/test\\0115.jpg', './dataset/test\\0116.jpg', './dataset/test\\0117.jpg', './dataset/test\\0118.jpg', './dataset/test\\0119.jpg', './dataset/test\\0120.jpg', './dataset/test\\0121.jpg', './dataset/test\\0122.jpg', './dataset/test\\0123.jpg', './dataset/test\\0124.jpg', './dataset/test\\0125.jpg', './dataset/test\\0126.jpg', './dataset/test\\0127.jpg', './dataset/test\\0128.jpg', './dataset/test\\0129.jpg', './dataset/test\\0130.jpg', './dataset/test\\0131.jpg', './dataset/test\\0132.jpg', './dataset/test\\0133.jpg', './dataset/test\\0134.jpg', './dataset/test\\0135.jpg', './dataset/test\\0136.jpg', './dataset/test\\0137.jpg', './dataset/test\\0138.jpg', './dataset/test\\0139.jpg', './dataset/test\\0140.jpg', './dataset/test\\0141.jpg', './dataset/test\\0142.jpg', './dataset/test\\0143. ...
# Model filename: ./models/20180402-114759.pb
# loaded classifier file->./models/my_classifier.pkl

# %%
predicted = pd.DataFrame(predicted)

predicted.to_csv('submission.csv', index=False)
predicted
# Out:
#       image-id         prediction
# 0            1         Faith Hill
# 1            2       Daniel Craig
# 2            3      John Travolta
# 3            4       Alec Baldwin
# 4            5  Michael Bloomberg
# ...        ...                ...
# 1655      1656    Stephen Colbert
# 1656      1657       Kate Winslet
# 1657      1658       Mariah Carey
# 1658      1659   Jennifer Aniston
# 1659      1660     George Clooney
#
# [1660 rows x 2 columns]

# %%
def get_test_image_paths(dir_path):
    image_paths = []
    if os.path.isdir(dir_path):
        images = os.listdir(dir_path)
        image_paths = [os.path.join(dir_path,img) for img in images]
    return image_paths

def load_dataset(path):
    dataset = []
    image_paths = get_test_image_paths(path)
    dataset.append(image_paths)
